# %% [markdown]
# # Preprocessing for yes/no question answering

# %% [markdown]
# Imports:

# %%
import pandas as pd
import json
import numpy as np
import country_converter as coco
from sklearn.tree import DecisionTreeClassifier, export_text

# %%
raw_df = pd.read_csv("./data/person_2025_small.csv")
# Ensure all columns are displayed
pd.set_option('display.max_columns', None)

# Example: Show the first 5 rows of a DataFrame `df`
print(raw_df.head())
# Out:
#          id   wd_id     wp_id            slug            name  \
# 0     18934   Q9458     18934        Muhammad        Muhammad
# 1      3395   Q9441      3395  Gautama_Buddha  Gautama Buddha
# 2     14627    Q935     14627    Isaac_Newton    Isaac Newton
# 3   4848272  Q22686   4848272    Donald_Trump    Donald Trump
# 4  17414699    Q720  17414699    Genghis_Khan    Genghis Khan
#
#            occupation  prob_ratio gender          twitter  alive    l  \
# 0    RELIGIOUS FIGURE         0.0      M              NaN  False  223
# 1         PHILOSOPHER         0.0      M              NaN  False  209
# 2           PHYSICIST         0.0      M              NaN  False  235
# 3          POLITICIAN         0.0      M  realDonaldTrump   True  253
# 4  MILITARY PERSONNEL         0.0      M              NaN  False  176
#
#      hpi_raw                  bplace_name  bplace_lat  bplace_lon  \
# 0  35.680259                        Mecca   21.422500   39.823333
# 1  35.495358                      Lumbini   27.481389   83.275833
# 2  35.480164  Woolsthorpe-by-Colsterworth   52.809863   -0.628770
# 3  35.418747                       Queens   40.750000  -73.866667
# 4  35.121570            Khentii Mountains   48.783300  109.167000
#
#    bplace_geonameid  bplace_country      birthdate  birthyear dplace_name  \
# 0           21021.0    Saudi Arabia            NaN        570      Medina
# 1          204326.0           Nepal  0566-04-08 BC       -566  Kushinagar
# 2          201088.0  United Kingdom     1643-01-04       1643  Kensington
# 3           45579.0   United States     1946-06-14       1946         NaN
# 4         7300427.0        Mongolia     1162-05-31       1162    Yinchuan
#
#    dplace_lat  dplace_lon  dplace_geonameid  dplace_country   deathdate  \
# 0      24.470      39.610           36636.0    Saudi Arabia  0632-06-08
# 1      26.741      83.888        33686220.0           India         NaN
# 2      51.500      -0.190           54732.0  United Kingdom  1727-03-31
# 3         NaN         NaN               NaN             NaN         NaN
# 4      38.485     106.225          465955.0           China  1227-08-18
#
#    deathyear          bplace_geacron_name dplace_geacron_name  is_group  \
# 0      632.0                        mecca              medina     False
# 1     -452.0                      lumbini          kushinagar     False
# 2     1726.0  woolsthorpe-by-colsterworth          kensington     False
# 3        NaN                       queens                 NaN     False
# 4     1227.0            khentii-mountains            yinchuan     False
#
#           l_  age  non_en_page_views  coefficient_of_variation         hpi
# 0  26.649583   62            3732407                  3.725079  100.000000
# 1  31.940636  114            2038657                  3.088739   99.481783
# 2  30.988775   83            2508822                  3.782160   99.439201
# 3  21.201757   79           17028468                  4.193298   99.267069
# 4  28.157479   65            2506097                  3.040899   98.434181

# %% [markdown]
# The idea is to: remove unnecessary columns (like id etc...) and then for each column create some relevant questions e.g. "Was the person born in the \[1900s/1800s/etc.\]?" from birthyear, or "Is the person a [Religious Figure/ Philosopher/ Physicist etc.]?" from occupation...

# %%
raw_df = raw_df[["name", "occupation", "gender", "alive", "bplace_name", "bplace_country", "birthyear", "dplace_name", "deathyear", "age" ]]
raw_df.head()
# Out:
#              name          occupation gender  alive  \
# 0        Muhammad    RELIGIOUS FIGURE      M  False
# 1  Gautama Buddha         PHILOSOPHER      M  False
# 2    Isaac Newton           PHYSICIST      M  False
# 3    Donald Trump          POLITICIAN      M   True
# 4    Genghis Khan  MILITARY PERSONNEL      M  False
#
#                    bplace_name  bplace_country  birthyear dplace_name  \
# 0                        Mecca    Saudi Arabia        570      Medina
# 1                      Lumbini           Nepal       -566  Kushinagar
# 2  Woolsthorpe-by-Colsterworth  United Kingdom       1643  Kensington
# 3                       Queens   United States       1946         NaN
# 4            Khentii Mountains        Mongolia       1162    Yinchuan
#
#    deathyear  age
# 0      632.0   62
# 1     -452.0  114
# 2     1726.0   83
# 3        NaN   79
# 4     1227.0   65

# %% [markdown]
# Let's encode occupations and age

# %%
def one_hot_occupations(occupation, top_n=20, top_occ=None):
    if not top_occ:
        return {}
    result = {}
    for occ in top_occ:
        if not isinstance(occ,str): 
            continue
        result[f"is_{occ.lower().replace(' ', '_')}"] = occupation.lower() == occ.lower()
    return result

def encode_age(age):
    return {
        "age_under_30": age < 30,
        "age_30_to_60": 30 <= age <= 60,
        "age_over_60": age > 60,
    }
    

def generate_year_buckets(df, col='birthyear', bin_width=50):
    min_year = int(df[col].min())
    max_year = int(df[col].max())

    min_bucket = (min_year // bin_width) * bin_width
    max_bucket = ((max_year // bin_width) + 1) * bin_width

    buckets = []
    for start in range(min_bucket, max_bucket, bin_width):
        end = start + bin_width
        label = f"born_{start}_{end - 1}"
        buckets.append((label, start, end))

    return buckets

def get_all_century_labels(df, col='birthyear'):
    min_century = int((df[col].min()) // 100) + 1
    max_century = int((df[col].max()) // 100) + 1
    return [century_label(c) for c in range(min_century, max_century + 1)]

def century_label(century):
    suffix = "th"
    if 10 < century % 100 < 14:
        suffix = "th"
    elif century % 10 == 1:
        suffix = "st"
    elif century % 10 == 2:
        suffix = "nd"
    elif century % 10 == 3:
        suffix = "rd"
    return f"born_in_{century}{suffix}_century"

def encode_birth_year(year, year_buckets, all_century_labels):
    traits = {}

    # 50-year buckets
    for label, start, end in year_buckets:
        traits[label] = start <= year < end

    # Century buckets (one-hot all)
    if pd.notnull(year):
        person_century = (year // 100) + 1
        for label in all_century_labels:
            traits[label] = label == century_label(person_century)
    else:
        for label in all_century_labels:
            traits[label] = False

    return traits

def get_all_countries(df, col="bplace_country"):
    countries = df[col].dropna().unique()
    return sorted([c.lower().replace(" ", "_") for c in countries if isinstance(c, str)])

def encode_country(country_name, all_countries):
    traits = {f"from_{c}": False for c in all_countries}
    if isinstance(country_name, str):
        key = country_name.lower().replace(" ", "_")
        if key in all_countries:
            traits[f"from_{key}"] = True
    return traits

    
ALL_CONTINENTS = ["africa", "antarctica", "asia", "europe", "america", "oceania"]

def encode_continent(country_name):
    traits = {f"from_{c.replace(' ', '_')}": False for c in ALL_CONTINENTS}
    try:
        
        continent = coco.convert(names=country_name, to='continent').lower()
        if continent in ALL_CONTINENTS:
            traits[f"from_{continent.replace(' ', '_')}"] = True
    except:
        pass  # leave all as False if conversion fails
    return traits

OCCUPATION_CATEGORIES = {
    "stem": [
        "scientist", "physicist", "chemist", "biologist", "mathematician", "statistician",
        "astronomer", "engineer", "inventor", "ecologist", "geologist", "roboticist", "computer scientist"
    ],
    "arts": [
        "artist", "painter", "sculptor", "photographer", "illustrator", "designer", "architect",
        "writer", "novelist", "poet", "screenwriter", "playwright",
        "actor", "actress", "director", "filmmaker", "dancer", "choreographer"
    ],
    "music": [
        "musician", "composer", "singer", "songwriter", "rapper", "pianist", "guitarist", "violinist", "dj"
    ],
    "sports": [
        "athlete", "footballer", "basketball player", "baseball player", "tennis player",
        "runner", "sprinter", "swimmer", "cyclist", "boxer", "wrestler", "skater", "coach",
        "cricketer", "golfer", "fencer", "gymnast", "judoka", "karateka"
    ],
    "media": [
        "journalist", "tv presenter", "radio host", "news anchor", "broadcaster", "youtuber", "podcaster", "influencer"
    ],
    "politics": [
        "politician", "president", "prime minister", "chancellor", "diplomat", "mayor", "senator", "governor", "ambassador", "monarch", "king", "queen", "emperor", "empress", "czar", "kaiser"
    ],
    "military": [
        "soldier", "general", "admiral", "commander", "officer", "warrior", "mercenary", "veteran"
    ],
    "business": [
        "entrepreneur", "businessperson", "executive", "ceo", "founder", "investor", "venture capitalist", "economist", "banker", "trader"
    ],
    "religion": [
        "priest", "monk", "nun", "theologian", "bishop", "cardinal", "imam", "rabbi", "pastor", "saint", "pope"
    ],
    "academia": [
        "professor", "academic", "philosopher", "historian", "linguist", "sociologist", "anthropologist", "archaeologist", "psychologist"
    ],
    "law": [
        "lawyer", "judge", "jurist", "prosecutor", "barrister"
    ],
    "crime": [
        "criminal", "mobster", "gangster", "assassin", "pirate", "serial killer", "terrorist"
    ],
    "royalty": [
        "king", "queen", "prince", "princess", "duke", "duchess", "emperor", "empress", "tsar", "pharaoh", "regent"
    ],
    "fictional": [
        "superhero", "villain", "fictional character", "wizard", "detective", "alien", "robot", "vampire", "god", "monster"
    ],
    "activism": [
        "activist", "feminist", "environmentalist", "revolutionary", "civil rights leader", "suffragist"
    ],
    "exploration": [
        "explorer", "navigator", "adventurer", "pioneer", "mountaineer", "astronaut"
    ],
    "misc": [
        "celebrity", "model", "beauty queen", "socialite", "pageant winner", "chef", "cook"
    ]
}


def encode_occupation_category(occupation, categories=OCCUPATION_CATEGORIES):
    traits = {f"is_{key}": False for key in categories}
    occ_lower = occupation.lower()
    matched = False

    for category, keywords in categories.items():
        for keyword in keywords:
            if keyword in occ_lower:
                traits[f"is_{category}"] = True
                matched = True
                break  # If you only want one category per person, keep this break

    if not matched:
        traits["is_other"] = True

    return traits

# %%
# Process each row
top_occupations = raw_df["occupation"].to_list()
processed = []
year_buckets = generate_year_buckets(raw_df, col='birthyear', bin_width=50)
century_labels = get_all_century_labels(raw_df, col='birthyear')
all_countries = get_all_countries(raw_df, col="bplace_country")
for _, row in raw_df.iterrows():
    traits = {
        "is_male": row["gender"] == "M",
        "is_alive": row["alive"],
    }
    traits.update(one_hot_occupations(row["occupation"], top_occ=top_occupations))
    traits.update(encode_birth_year(row['birthyear'], year_buckets, century_labels)) 
    traits.update(encode_age(row["age"]))
    #traits.update(encode_country(row["bplace_country"]))
    traits.update(encode_occupation_category(row["occupation"]))
    traits.update(encode_continent(row["bplace_country"]))
    traits.update(encode_country(row["bplace_country"], all_countries))
    processed.append({
        "name": row["name"],
        "traits": traits
    })

# Save to JSON
with open("processed_characters.json", "w") as f:
    json.dump(processed, f, indent=2)

# %% [markdown]
# ## Let's build a Decision Tree on it

# %%
# Load your preprocessed JSON
with open("processed_characters.json") as f:
    data = json.load(f)

# Build DataFrame
names = []
traits_list = []
for entry in data:
    names.append(entry["name"])
    traits_list.append(entry["traits"])

df = pd.DataFrame(traits_list)
df["name"] = names

# Encode names as target classes
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df["name"])
X = df.drop(columns=["name"])

# Train Decision Tree
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion="entropy", max_depth=10)  # limit depth to avoid overfitting
clf.fit(X, y)

# Print the decision tree structure as text
tree_text = export_text(clf, feature_names=list(X.columns))
print(tree_text)
# Out:
# |--- from_europe <= 0.50
# |   |--- from_asia <= 0.50
# |   |   |--- born_in_20th_century <= 0.50
# |   |   |   |--- from_united_states <= 0.50
# |   |   |   |   |--- from_egypt <= 0.50
# |   |   |   |   |   |--- from_africa <= 0.50
# |   |   |   |   |   |   |--- born_-1050_-1001 <= 0.50
# |   |   |   |   |   |   |   |--- class: 123
# |   |   |   |   |   |   |--- born_-1050_-1001 >  0.50
# |   |   |   |   |   |   |   |--- class: 128
# |   |   |   |   |   |--- from_africa >  0.50
# |   |   |   |   |   |   |--- is_philosopher <= 0.50
# |   |   |   |   |   |   |   |--- class: 66
# |   |   |   |   |   |   |--- is_philosopher >  0.50
# |   |   |   |   |   |   |   |--- class: 13
# |   |   |   |   |--- from_egypt >  0.50
# |   |   |   |   |   |--- is_mathematician <= 0.50
# |   |   |   |   |   |   |--- age_over_60 <= 0.50
# |   |   |   |   |   |   |   |--- class: 27
# |   |   |   |   |   |   |--- age_over_60 >  0.50
# |   |   |   |   |   |   |   |--- class: 97
# |   |   |   |   |   |--- is_mathematician >  0.50
# |   |   |   |   |   |   |--- class: 40
# |   |   |   |--- from_united_states >  0.50
# |   |   |   |   |--- born_in_18th_century <= 0.50
# |   |   |   |   |   |--- is_politics <= 0.50
# |   |   |   |   |   |   |--- is_stem <= 0.50
# |   |   |   |   |   |   |   |--- class: 33
# |   |   |   |   |   |   |--- is_stem >  0.50
# |   |   |   |   |   |   |   |--- class: 132
# |   |   |   |   |   |--- is_politics >  0.50
# |   |   |   |   |   |   |--- age_over_60 <= 0.50
# |   |   |   |   |   |   |   |--- class: 143
# |   |   |   |   |   |   |--- age_over_60 >  0.50
# |   |   |   |   |   |   |   |--- class: 135
# |   |   |   |   |--- born_in_18th_century >  0.50
# |   |   |   |   |   |--- born_1700_1749 <= 0.50
# |   |   |   |   |   |   |--- class: 9
# |   |   |   |   |   |--- born_1700_1749 >  0.50
# |   |   |   |   |   |   |--- class: 133
# |   |   |--- born_in_20th_century >  0.50
# |   |   |   |--- is_alive <= 0.50
# |   |   |   |   |--- from_united_states <= 0.50
# |   |   |   |   |   |--- age_30_to_60 <= 0.50
# |   |   |   |   |   |   |--- from_argentina <= 0.50
# |   |   |   |   |   |   |   |--- class: 104
# |   |   |   |   |   |   |--- from_argentina >  0.50
# |   |   |   |   |   |   |   |--- class: 112
# |   |   |   |   |   |--- age_30_to_60 >  0.50
# |   |   |   |   |   |   |--- from_mexico <= 0.50
# |   |   |   |   |   |   |   |--- class: 25
# |   |   |   |   |   |   |--- from_mexico >  0.50
# |   |   |   |   |   |   |   |--- class: 46
# |   |   |   |   |--- from_united_states >  0.50
# |   |   |   |   |   |--- is_politics <= 0.50
# |   |   |   |   |   |   |--- is_sports <= 0.50
# |   |   |   |   |   |   |   |--- is_physicist <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |--- is_physicist >  0.50
# |   |   |   |   |   |   |   |   |--- class: 67
# |   |   |   |   |   |   |--- is_sports >  0.50
# |   |   |   |   |   |   |   |--- class: 100
# |   |   |   |   |   |--- is_politics >  0.50
# |   |   |   |   |   |   |--- class: 72
# |   |   |   |--- is_alive >  0.50
# |   |   |   |   |--- is_actor <= 0.50
# |   |   |   |   |   |--- is_politics <= 0.50
# |   |   |   |   |   |   |--- class: 115
# |   |   |   |   |   |--- is_politics >  0.50
# |   |   |   |   |   |   |--- class: 32
# |   |   |   |   |--- is_actor >  0.50
# |   |   |   |   |   |--- class: 4
# |   |--- from_asia >  0.50
# |   |   |--- is_politician <= 0.50
# |   |   |   |--- is_religious_figure <= 0.50
# |   |   |   |   |--- is_philosopher <= 0.50
# |   |   |   |   |   |--- is_military_personnel <= 0.50
# |   |   |   |   |   |   |--- is_mathematician <= 0.50
# |   |   |   |   |   |   |   |--- is_historian <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |--- is_historian >  0.50
# |   |   |   |   |   |   |   |   |--- class: 59
# |   |   |   |   |   |   |--- is_mathematician >  0.50
# |   |   |   |   |   |   |   |--- class: 101
# |   |   |   |   |   |--- is_military_personnel >  0.50
# |   |   |   |   |   |   |--- born_1150_1199 <= 0.50
# |   |   |   |   |   |   |   |--- class: 134
# |   |   |   |   |   |   |--- born_1150_1199 >  0.50
# |   |   |   |   |   |   |   |--- class: 52
# |   |   |   |   |--- is_philosopher >  0.50
# |   |   |   |   |   |--- age_over_60 <= 0.50
# |   |   |   |   |   |   |--- born_-650_-601 <= 0.50
# |   |   |   |   |   |   |   |--- class: 15
# |   |   |   |   |   |   |--- born_-650_-601 >  0.50
# |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |--- age_over_60 >  0.50
# |   |   |   |   |   |   |--- from_china <= 0.50
# |   |   |   |   |   |   |   |--- class: 51
# |   |   |   |   |   |   |--- from_china >  0.50
# |   |   |   |   |   |   |   |--- class: 30
# |   |   |   |--- is_religious_figure >  0.50
# |   |   |   |   |--- born_in_0th_century <= 0.50
# |   |   |   |   |   |--- from_saudi_arabia <= 0.50
# |   |   |   |   |   |   |--- born_in_-18nd_century <= 0.50
# |   |   |   |   |   |   |   |--- class: 109
# |   |   |   |   |   |   |--- born_in_-18nd_century >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- from_saudi_arabia >  0.50
# |   |   |   |   |   |   |--- age_30_to_60 <= 0.50
# |   |   |   |   |   |   |   |--- class: 99
# |   |   |   |   |   |   |--- age_30_to_60 >  0.50
# |   |   |   |   |   |   |   |--- class: 8
# |   |   |   |   |--- born_in_0th_century >  0.50
# |   |   |   |   |   |--- born_-50_-1 <= 0.50
# |   |   |   |   |   |   |--- is_male <= 0.50
# |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |--- is_male >  0.50
# |   |   |   |   |   |   |   |--- class: 122
# |   |   |   |   |   |--- born_-50_-1 >  0.50
# |   |   |   |   |   |   |--- class: 71
# |   |   |--- is_politician >  0.50
# |   |   |   |--- age_30_to_60 <= 0.50
# |   |   |   |   |--- born_1850_1899 <= 0.50
# |   |   |   |   |   |--- born_in_16th_century <= 0.50
# |   |   |   |   |   |   |--- from_china <= 0.50
# |   |   |   |   |   |   |   |--- is_male <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 64
# |   |   |   |   |   |   |   |--- is_male >  0.50
# |   |   |   |   |   |   |   |   |--- class: 130
# |   |   |   |   |   |   |--- from_china >  0.50
# |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |--- born_in_16th_century >  0.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- born_1850_1899 >  0.50
# |   |   |   |   |   |--- from_georgia <= 0.50
# |   |   |   |   |   |   |--- class: 62
# |   |   |   |   |   |--- from_georgia >  0.50
# |   |   |   |   |   |   |--- class: 78
# |   |   |   |--- age_30_to_60 >  0.50
# |   |   |   |   |--- from_iraq <= 0.50
# |   |   |   |   |   |--- born_1400_1449 <= 0.50
# |   |   |   |   |   |   |--- born_in_-2th_century <= 0.50
# |   |   |   |   |   |   |   |--- class: 136
# |   |   |   |   |   |   |--- born_in_-2th_century >  0.50
# |   |   |   |   |   |   |   |--- class: 118
# |   |   |   |   |   |--- born_1400_1449 >  0.50
# |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |--- from_iraq >  0.50
# |   |   |   |   |   |--- class: 124
# |--- from_europe >  0.50
# |   |--- age_over_60 <= 0.50
# |   |   |--- is_politics <= 0.50
# |   |   |   |--- is_arts <= 0.50
# |   |   |   |   |--- born_in_15th_century <= 0.50
# |   |   |   |   |   |--- is_composer <= 0.50
# |   |   |   |   |   |   |--- is_academia <= 0.50
# |   |   |   |   |   |   |   |--- is_stem <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |--- is_stem >  0.50
# |   |   |   |   |   |   |   |   |--- born_1550_1599 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 17
# |   |   |   |   |   |   |   |   |--- born_1550_1599 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 77
# |   |   |   |   |   |   |--- is_academia >  0.50
# |   |   |   |   |   |   |   |--- born_1600_1649 <= 0.50
# |   |   |   |   |   |   |   |   |--- from_germany <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 121
# |   |   |   |   |   |   |   |   |--- from_germany >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 47
# |   |   |   |   |   |   |   |--- born_1600_1649 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 16
# |   |   |   |   |   |--- is_composer >  0.50
# |   |   |   |   |   |   |--- born_in_19th_century <= 0.50
# |   |   |   |   |   |   |   |--- from_germany <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 145
# |   |   |   |   |   |   |   |--- from_germany >  0.50
# |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |--- born_in_19th_century >  0.50
# |   |   |   |   |   |   |   |--- from_poland <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 116
# |   |   |   |   |   |   |   |--- from_poland >  0.50
# |   |   |   |   |   |   |   |   |--- class: 48
# |   |   |   |   |--- born_in_15th_century >  0.50
# |   |   |   |   |   |--- from_italy <= 0.50
# |   |   |   |   |   |   |--- born_1450_1499 <= 0.50
# |   |   |   |   |   |   |   |--- class: 73
# |   |   |   |   |   |   |--- born_1450_1499 >  0.50
# |   |   |   |   |   |   |   |--- from_portugal <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 58
# |   |   |   |   |   |   |   |--- from_portugal >  0.50
# |   |   |   |   |   |   |   |   |--- class: 41
# |   |   |   |   |   |--- from_italy >  0.50
# |   |   |   |   |   |   |--- is_academia <= 0.50
# |   |   |   |   |   |   |   |--- class: 26
# |   |   |   |   |   |   |--- is_academia >  0.50
# |   |   |   |   |   |   |   |--- class: 105
# |   |   |   |--- is_arts >  0.50
# |   |   |   |   |--- born_in_19th_century <= 0.50
# |   |   |   |   |   |--- born_1450_1499 <= 0.50
# |   |   |   |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |   |   |   |--- from_greece <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 31
# |   |   |   |   |   |   |   |--- from_greece >  0.50
# |   |   |   |   |   |   |   |   |--- class: 61
# |   |   |   |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |   |   |   |--- class: 144
# |   |   |   |   |   |--- born_1450_1499 >  0.50
# |   |   |   |   |   |   |--- from_italy <= 0.50
# |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |--- from_italy >  0.50
# |   |   |   |   |   |   |   |--- class: 119
# |   |   |   |   |--- born_in_19th_century >  0.50
# |   |   |   |   |   |--- from_netherlands <= 0.50
# |   |   |   |   |   |   |--- born_1850_1899 <= 0.50
# |   |   |   |   |   |   |   |--- class: 49
# |   |   |   |   |   |   |--- born_1850_1899 >  0.50
# |   |   |   |   |   |   |   |--- from_czechia <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 68
# |   |   |   |   |   |   |   |--- from_czechia >  0.50
# |   |   |   |   |   |   |   |   |--- class: 45
# |   |   |   |   |   |--- from_netherlands >  0.50
# |   |   |   |   |   |   |--- class: 139
# |   |   |--- is_politics >  0.50
# |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |--- born_1850_1899 <= 0.50
# |   |   |   |   |   |--- born_1750_1799 <= 0.50
# |   |   |   |   |   |   |--- born_in_0th_century <= 0.50
# |   |   |   |   |   |   |   |--- class: 29
# |   |   |   |   |   |   |--- born_in_0th_century >  0.50
# |   |   |   |   |   |   |   |--- class: 79
# |   |   |   |   |   |--- born_1750_1799 >  0.50
# |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |--- born_1850_1899 >  0.50
# |   |   |   |   |   |--- from_austria <= 0.50
# |   |   |   |   |   |   |--- from_greece <= 0.50
# |   |   |   |   |   |   |   |--- class: 140
# |   |   |   |   |   |   |--- from_greece >  0.50
# |   |   |   |   |   |   |   |--- class: 102
# |   |   |   |   |   |--- from_austria >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |--- born_in_16th_century <= 0.50
# |   |   |   |   |   |--- born_1600_1649 <= 0.50
# |   |   |   |   |   |   |--- class: 54
# |   |   |   |   |   |--- born_1600_1649 >  0.50
# |   |   |   |   |   |   |--- class: 22
# |   |   |   |   |--- born_in_16th_century >  0.50
# |   |   |   |   |   |--- born_1500_1549 <= 0.50
# |   |   |   |   |   |   |--- class: 69
# |   |   |   |   |   |--- born_1500_1549 >  0.50
# |   |   |   |   |   |   |--- class: 34
# |   |--- age_over_60 >  0.50
# |   |   |--- born_in_19th_century <= 0.50
# |   |   |   |--- is_stem <= 0.50
# |   |   |   |   |--- born_in_20th_century <= 0.50
# |   |   |   |   |   |--- is_philosopher <= 0.50
# |   |   |   |   |   |   |--- born_in_17th_century <= 0.50
# |   |   |   |   |   |   |   |--- is_arts <= 0.50
# |   |   |   |   |   |   |   |   |--- is_politician <= 0.50
# |   |   |   |   |   |   |   |   |   |--- born_in_15th_century <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- born_in_15th_century >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |--- is_politician >  0.50
# |   |   |   |   |   |   |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 14
# |   |   |   |   |   |   |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 37
# |   |   |   |   |   |   |   |--- is_arts >  0.50
# |   |   |   |   |   |   |   |   |--- born_in_18th_century <= 0.50
# |   |   |   |   |   |   |   |   |   |--- is_painter <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 129
# |   |   |   |   |   |   |   |   |   |--- is_painter >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 96
# |   |   |   |   |   |   |   |   |--- born_in_18th_century >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 75
# |   |   |   |   |   |   |--- born_in_17th_century >  0.50
# |   |   |   |   |   |   |   |--- is_composer <= 0.50
# |   |   |   |   |   |   |   |   |--- is_arts <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |--- is_arts >  0.50
# |   |   |   |   |   |   |   |   |   |--- born_1600_1649 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 142
# |   |   |   |   |   |   |   |   |   |--- born_1600_1649 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 120
# |   |   |   |   |   |   |   |--- is_composer >  0.50
# |   |   |   |   |   |   |   |   |--- from_italy <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 74
# |   |   |   |   |   |   |   |   |--- from_italy >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 10
# |   |   |   |   |   |--- is_philosopher >  0.50
# |   |   |   |   |   |   |--- from_greece <= 0.50
# |   |   |   |   |   |   |   |--- from_switzerland <= 0.50
# |   |   |   |   |   |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 63
# |   |   |   |   |   |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 43
# |   |   |   |   |   |   |   |--- from_switzerland >  0.50
# |   |   |   |   |   |   |   |   |--- class: 70
# |   |   |   |   |   |   |--- from_greece >  0.50
# |   |   |   |   |   |   |   |--- born_in_-4th_century <= 0.50
# |   |   |   |   |   |   |   |   |--- born_-600_-551 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 12
# |   |   |   |   |   |   |   |   |--- born_-600_-551 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 117
# |   |   |   |   |   |   |   |--- born_in_-4th_century >  0.50
# |   |   |   |   |   |   |   |   |--- born_-500_-451 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 110
# |   |   |   |   |   |   |   |   |--- born_-500_-451 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 127
# |   |   |   |   |--- born_in_20th_century >  0.50
# |   |   |   |   |   |--- is_religious_figure <= 0.50
# |   |   |   |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |   |   |   |--- is_activism <= 0.50
# |   |   |   |   |   |   |   |   |--- from_russia <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 125
# |   |   |   |   |   |   |   |   |--- from_russia >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 141
# |   |   |   |   |   |   |   |--- is_activism >  0.50
# |   |   |   |   |   |   |   |   |--- class: 98
# |   |   |   |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |   |   |   |--- is_alive <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 38
# |   |   |   |   |   |   |   |--- is_alive >  0.50
# |   |   |   |   |   |   |   |   |--- class: 23
# |   |   |   |   |   |--- is_religious_figure >  0.50
# |   |   |   |   |   |   |--- from_poland <= 0.50
# |   |   |   |   |   |   |   |--- from_italy <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 111
# |   |   |   |   |   |   |   |--- from_italy >  0.50
# |   |   |   |   |   |   |   |   |--- class: 113
# |   |   |   |   |   |   |--- from_poland >  0.50
# |   |   |   |   |   |   |   |--- class: 114
# |   |   |   |--- is_stem >  0.50
# |   |   |   |   |--- is_mathematician <= 0.50
# |   |   |   |   |   |--- is_astronomer <= 0.50
# |   |   |   |   |   |   |--- is_inventor <= 0.50
# |   |   |   |   |   |   |   |--- is_physicist <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 19
# |   |   |   |   |   |   |   |--- is_physicist >  0.50
# |   |   |   |   |   |   |   |   |--- class: 65
# |   |   |   |   |   |   |--- is_inventor >  0.50
# |   |   |   |   |   |   |   |--- born_in_14th_century <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |--- born_in_14th_century >  0.50
# |   |   |   |   |   |   |   |   |--- class: 76
# |   |   |   |   |   |--- is_astronomer >  0.50
# |   |   |   |   |   |   |--- born_in_16th_century <= 0.50
# |   |   |   |   |   |   |   |--- class: 106
# |   |   |   |   |   |   |--- born_in_16th_century >  0.50
# |   |   |   |   |   |   |   |--- class: 50
# |   |   |   |   |--- is_mathematician >  0.50
# |   |   |   |   |   |--- from_germany <= 0.50
# |   |   |   |   |   |   |--- born_in_12th_century <= 0.50
# |   |   |   |   |   |   |   |--- class: 11
# |   |   |   |   |   |   |--- born_in_12th_century >  0.50
# |   |   |   |   |   |   |   |--- class: 42
# |   |   |   |   |   |--- from_germany >  0.50
# |   |   |   |   |   |   |--- born_in_18th_century <= 0.50
# |   |   |   |   |   |   |   |--- class: 56
# |   |   |   |   |   |   |--- born_in_18th_century >  0.50
# |   |   |   |   |   |   |   |--- class: 18
# |   |   |--- born_in_19th_century >  0.50
# |   |   |   |--- born_1800_1849 <= 0.50
# |   |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |   |--- is_physicist <= 0.50
# |   |   |   |   |   |   |--- is_painter <= 0.50
# |   |   |   |   |   |   |   |--- is_academia <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 107
# |   |   |   |   |   |   |   |--- is_academia >  0.50
# |   |   |   |   |   |   |   |   |--- class: 126
# |   |   |   |   |   |   |--- is_painter >  0.50
# |   |   |   |   |   |   |   |--- class: 108
# |   |   |   |   |   |--- is_physicist >  0.50
# |   |   |   |   |   |   |--- from_poland <= 0.50
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- from_poland >  0.50
# |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |   |--- is_politician <= 0.50
# |   |   |   |   |   |   |--- class: 24
# |   |   |   |   |   |--- is_politician >  0.50
# |   |   |   |   |   |   |--- class: 36
# |   |   |   |--- born_1800_1849 >  0.50
# |   |   |   |   |--- is_arts <= 0.50
# |   |   |   |   |   |--- from_united_kingdom <= 0.50
# |   |   |   |   |   |   |--- from_germany <= 0.50
# |   |   |   |   |   |   |   |--- is_chemist <= 0.50
# |   |   |   |   |   |   |   |   |--- from_italy <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 44
# |   |   |   |   |   |   |   |   |--- from_italy >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 55
# |   |   |   |   |   |   |   |--- is_chemist >  0.50
# |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |--- from_germany >  0.50
# |   |   |   |   |   |   |   |--- is_companion <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 80
# |   |   |   |   |   |   |   |--- is_companion >  0.50
# |   |   |   |   |   |   |   |   |--- class: 39
# |   |   |   |   |   |--- from_united_kingdom >  0.50
# |   |   |   |   |   |   |--- is_stem <= 0.50
# |   |   |   |   |   |   |   |--- class: 35
# |   |   |   |   |   |   |--- is_stem >  0.50
# |   |   |   |   |   |   |   |--- class: 21
# |   |   |   |   |--- is_arts >  0.50
# |   |   |   |   |   |--- from_russia <= 0.50
# |   |   |   |   |   |   |--- from_denmark <= 0.50
# |   |   |   |   |   |   |   |--- class: 138
# |   |   |   |   |   |   |--- from_denmark >  0.50
# |   |   |   |   |   |   |   |--- class: 57
# |   |   |   |   |   |--- from_russia >  0.50
# |   |   |   |   |   |   |--- class: 83

# %%
def ask_tree_questions(clf, X_columns, label_encoder):
    tree = clf.tree_
    node = 0  # start at root

    while tree.children_left[node] != tree.children_right[node]:  # while not a leaf
        feature_idx = tree.feature[node]
        feature_name = X_columns[feature_idx]

        # Ask user
        answer = input(f"Is the answer to '{feature_name.replace('_', ' ')}' yes? (y/n) ").strip().lower()
        if answer == "y":
            node = tree.children_right[node]
        else:
            node = tree.children_left[node]

    # Predict class (majority vote in this leaf)
    class_id = tree.value[node].argmax()
    prediction = label_encoder.inverse_transform([class_id])[0]
    print(f"\n🧠 I guess: {prediction}")

# %%
ask_tree_questions(clf, X.columns.tolist(), label_encoder)
# Out:
# 🧠 I guess: Pope Francis
